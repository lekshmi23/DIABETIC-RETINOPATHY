# %% [markdown]
# NAIVE Classifier

# %%
import pickle
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import svm
from  sklearn.metrics import plot_confusion_matrix 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.naive_bayes import GaussianNB



feat_path='/content/drive/MyDrive/NEW DR FOLDER/feature.pkl'
label_path='/content/drive/MyDrive/NEW DR FOLDER/label.pkl'
f = open(feat_path, 'rb')
feat=pickle.load(f)
f.close()
f = open(label_path, 'rb')
label=pickle.load(f)
f.close()

X=np.array(feat)
y=np.array(label)
X_train, X_test, y_train, y_test = train_test_split(
             X, y, test_size = 0.2)

gnb = GaussianNB()

gnb.fit(X, y)


print(gnb.score(X_train, y_train))
plot_confusion_matrix(gnb,X_train, y_train)
plt.title('NaiveBayes Classifier - Confusion Matrix - Training')
plt.show()
print(gnb.score(X_test, y_test))
plot_confusion_matrix(gnb,X_test, y_test)
plt.title('NaiveBayes Classifier - Confusion Matrix - Testing')
plt.show()
# Out:
# 0.9691176470588235
# 0.9766081871345029

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Total Feature Size',X.shape)
print('Abnormal' ,np.sum(y))
print('Normal' ,y.shape[0]-np.sum(y))
print('Train Size',X_train.shape)
print('Abnormal' ,np.sum(y_train))
print('Normal' ,y_train.shape[0]-np.sum(y_train))
print('Test Size',X_test.shape)
print('Abnormal' ,np.sum(y_test))
print('Normal' ,y_test.shape[0]-np.sum(y_test))
# Out:
# Total Feature Size (851, 50)
# Abnormal 296
# Normal 555
# Train Size (680, 50)
# Abnormal 234
# Normal 446
# Test Size (171, 50)
# Abnormal 62
# Normal 109

# %%
from sklearn import metrics
confusion = metrics.confusion_matrix(y_train,gnb.predict(X_train) )
print(confusion)
# Out:
# [[428  18]
#  [  3 231]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
total1=sum(sum(confusion))
Accuracy = (confusion[0,0]+confusion[1,1])/total1
Specificity = confusion[0,0]/(confusion[0,0]+confusion[0,1])
Sensitivity = confusion[1,1]/(confusion[1,0]+confusion[1,1])
print('Accuracy :',Accuracy)
print(' Specificity:',Specificity)
print('Sensitivity :',Sensitivity)
# Out:
# Accuracy : 0.9691176470588235
#  Specificity: 0.9596412556053812
# Sensitivity : 0.9871794871794872

# %%
from sklearn import metrics
confusion = metrics.confusion_matrix(y_test,gnb.predict(X_test) )
print(confusion)
# Out:
# [[105   4]
#  [  0  62]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
total1=sum(sum(confusion))
Accuracy = (confusion[0,0]+confusion[1,1])/total1
Specificity = confusion[0,0]/(confusion[0,0]+confusion[0,1])
Sensitivity = confusion[1,1]/(confusion[1,0]+confusion[1,1])
print('Accuracy :',Accuracy)
print(' Specificity:',Specificity)
print('Sensitivity :',Sensitivity)
# Out:
# Accuracy : 0.9766081871345029
#  Specificity: 0.963302752293578
# Sensitivity : 1.0
